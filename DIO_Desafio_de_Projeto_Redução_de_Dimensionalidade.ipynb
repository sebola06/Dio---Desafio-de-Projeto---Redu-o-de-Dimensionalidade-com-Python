# %% [markdown]
# <a href="https://colab.research.google.com/github/sebola06/Dio---Desafio-de-Projeto---Redu-o-de-Dimensionalidade-com-Python/blob/main/DIO_Desafio_de_Projeto_Redu%C3%A7%C3%A3o_de_Dimensionalidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
imagem = mpimg.imread('/content/sample_data/ja_sabe_ne.jpg')
imagem = np.array(imagem)
plt.imshow(imagem)

# %%
imagem_tons_de_cinza = 0.2989*imagem[:,:,0] + 0.5870*imagem[:,:,1] + 0.1140*imagem[:,:,2]
plt.imshow(imagem_tons_de_cinza, cmap='gray')

# %%
imagem_binaria = imagem_tons_de_cinza > 127
plt.imshow(imagem_binaria, cmap='gray')

# %%
plt.subplot(1, 3, 1)
plt.axis('off')
plt.imshow(imagem)
plt.subplot(1, 3, 2)
plt.axis('off')
plt.imshow(imagem_tons_de_cinza, cmap='gray')
plt.subplot(1, 3, 3)
plt.axis('off')
plt.imshow(imagem_binaria, cmap='gray')
plt.show()
